# %%
import math
from part2_lib import *

# %%
public_key = (65537,...)

cipher = "..."

# %%
# public key = (pq, e)
e = public_key[0]
n = public_key[1] # pq

# %%
n >= isqrt(n) * isqrt(n)
# Out:
# True

# %%
p = ...
q = ...

# %% [markdown]
# # Goal
#
# 1. Find possible p, q
# 2. ```d = modinv(e, (p-1)*(q-1))```
# 3. flag = $cipher^d \  mod (n)$

# %%
d = modinv(e, (p-1)*(q-1))

# %%
from Crypto.PublicKey import RSA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-b6fe4d249eef> in <module>
# ----> 1 from Crypto.PublicKey import RSA
#
# ModuleNotFoundError: No module named 'Crypto'

# %%
key=RSA.construct((n,e,d,p,q))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f82c6a5c2db0> in <module>
# ----> 1 key=RSA.construct((n,e,d,p,q))
#
# NameError: name 'RSA' is not defined

# %%
bcipher = bytes(cipher, 'ascii')

# %%
key.decrypt(bcipher)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-209c8e79ba95> in <module>
# ----> 1 key.decrypt(bcipher)
#
# NameError: name 'key' is not defined
